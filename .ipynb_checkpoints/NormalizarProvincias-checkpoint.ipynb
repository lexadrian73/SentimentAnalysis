# %%
import json
import re
import pandas as pd
import numpy as np


f = open('dis_ec.json', encoding="utf8")
  
data = json.load(f)


dict_provincias = []
for k, v in data.items():
    if not (data[k].get('provincia') is None):
        dict_provincias.append({
            'id' : k,
            'provincia' : data[k]['provincia']
        })
        
dict_cantones = []      
for k, v in data.items():
    if not (data[k].get('provincia') is None):
        for k_2, v_2 in data[k]['cantones'].items():
            dict_cantones.append({ 
                'id' : k,
                'provincia' : data[k]['provincia'],
                'canton' : data[k]['cantones'][k_2]['canton']
            })

df = pd.read_csv('tweets_Correa.csv', low_memory=False)
location_column = df['location']

location_list = df['location'].tolist()

location_list=['no ubicacion' if x is np.nan else x for x in location_list]

location_column_regex = []
copy_location = []

for string in location_list:
    if(string != None):
        change_string = re.sub(r'[ ](?=[ ])|[^A-Za-z ]+', ' ', string)
        change_string = change_string.lower().replace('ecuador', '').strip()
        location_column_regex.append(change_string)
        
copy_location = location_column_regex.copy()

for i in range(len(copy_location)):
    if copy_location[i] == '':
        copy_location[i] = 'no ubicacion'
    

#for i in range(len(copy_location)):
#    for j in dict_provincias:
#        print(j['provincia'].lower() + " " + copy_location[i])
        


for i in range(len(copy_location)):
    for j in dict_cantones:
        if j['canton'].lower() == copy_location[i]:
            copy_location[i] = j['provincia'].lower()
            #print(j['canton'].lower() + " " + copy_location[i])
        
#B

for i in range(len(copy_location)):
    for j in dict_cantones:
        if len(copy_location[i].split()) > 1:
            for c in copy_location[i].split():
                if j['canton'].lower() == c.strip():
                    copy_location[i] = j['provincia'].lower()
            
#print(copy_location)
# Out:
# ['manabi', 'pichincha', 'azuay', 'azuay', 'pichincha', 'el oro', 'no ubicacion', 'pichincha', 'guayas', 'azuay', 'no ubicacion', 'vinces', 'manabi', 'por el camino yo me entretengo', 'por el camino yo me entretengo', 'manabi', 'por el camino yo me entretengo', 'pichincha', 'por el camino yo me entretengo', 'por el camino yo me entretengo', 'por el camino yo me entretengo', 'santa elena', 'pichincha', 'sucumbios', 'no ubicacion', 'pichincha', 'pichincha', 'pichincha', 'manabi', 'manabi', 'pichincha', 'pichincha', 'azuay', 'pichincha', 'pichincha', 'pichincha', 'azuay', 'por el camino yo me entretengo', 'por el camino yo me entretengo', 'pichincha', 'por el camino yo me entretengo', 'pichincha', 'azuay', 'por el camino yo me entretengo', 'pichincha', 'por el camino yo me entretengo', 'por el camino yo me entretengo', 'pichincha', 'manabi', 'pichincha', 'esmeraldas', 'pichincha', 'pichincha', 'no ubicacion', 'pichincha', 'pichincha', 'pichincha', 'pichincha', 'no ubicacion', 'azuay', 'azuay', 'no ubicacion', 'azuay', 'no ubicacion', 'pichincha', 'manabi', 'tena  napo', 'no ubicacion', 'santa lucia   guayas', 'daule   guayas', 'no ubicacion', 'daule   guayas', 'santa lucia   guayas', 'no ubicacion', 'no ubicacion', 'no ubicacion', 'no ubicacion', 